# %% [markdown]
# # Zero-Shot Pre-Labeling

# %% [markdown]
# Manually reading 1,440 reviews and tagging them would take hours. Instead, we will use a Zero-Shot Text Classification model. "Zero-shot" means the model doesn't need to be trained on PickMe reviews; it already understands English well enough to sort text into any categories give it.

# %%
import pandas as pd
from transformers import pipeline
from tqdm import tqdm

# %% [markdown]
# Load English reviews

# %%
df_en = pd.read_csv('../data/raw/pickme_reviews_with_sentiment.csv')
df_en = df_en[df_en['language'] == 'English'].copy().reset_index(drop=True)

# %% [markdown]
# Define the categories

# %%
candidate_labels = [
    "App bugs and technical issues",
    "Pricing, surge, and bidding",
    "Food delivery delays and missing items",
    "Driver behavior and safety",
    "Customer support and refunds",
    "Privacy and security concerns"
]

# %% [markdown]
# Initialize the zero-shot pipeline

# %%
print("Loading model...")
classifier = pipeline(
    "zero-shot-classification", 
    model="facebook/bart-large-mnli", 
    device=0
)
# Out:
# Loading model...
# ...
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.63GB
# model.safetensors: downloading bytes:           |  0.00B
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 print("Loading model...")
# ----> 2 classifier = pipeline(
#       3     "zero-shot-classification",
#       4     model="facebook/bart-large-mnli",
#       5     device=0
#       6 )
#
# File c:\Users\a12u\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\__init__.py:1033, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1031 if isinstance(model, str):
# ...
